# %%
def convert_to_ms(value):
    if value.endswith('ms'):
        return float(value[:-2])
    elif value.endswith('us'):
        return float(value[:-2]) / 1000
    elif value.endswith('s'):
        return float(value[:-1]) * 1000
    else:
        return float(value)
    
data = [
{'test_name': 'httpgobin-t1-c10', 'threads': '1', 'connections': '10', 'latency': {'avg': '577.26us', 'stddev': '581.89us', 'max': '21.46ms'}, 'requests_per_second': '18878.93'},
{'test_name': 'httpgobin-t2-c10', 'threads': '2', 'connections': '10', 'latency': {'avg': '439.47us', 'stddev': '303.04us', 'max': '10.62ms'}, 'requests_per_second': '22968.07'},
{'test_name': 'httpgobin-t3-c10', 'threads': '3', 'connections': '10', 'latency': {'avg': '415.95us', 'stddev': '266.25us', 'max': '10.53ms'}, 'requests_per_second': '21802.75'},
{'test_name': 'httpgobin-t4-c10', 'threads': '4', 'connections': '10', 'latency': {'avg': '685.01us', 'stddev': '1.03ms', 'max': '20.14ms'}, 'requests_per_second': '15948.87'},
{'test_name': 'httpgobin-t1-c20', 'threads': '1', 'connections': '20', 'latency': {'avg': '686.21us', 'stddev': '425.21us', 'max': '12.12ms'}, 'requests_per_second': '29268.84'},
{'test_name': 'httpgobin-t2-c20', 'threads': '2', 'connections': '20', 'latency': {'avg': '1.30ms', 'stddev': '1.82ms', 'max': '32.31ms'}, 'requests_per_second': '21133.84'},
{'test_name': 'httpgobin-t3-c20', 'threads': '3', 'connections': '20', 'latency': {'avg': '641.25us', 'stddev': '373.00us', 'max': '13.70ms'}, 'requests_per_second': '28311.92'},
{'test_name': 'httpgobin-t4-c20', 'threads': '4', 'connections': '20', 'latency': {'avg': '1.35ms', 'stddev': '2.39ms', 'max': '58.94ms'}, 'requests_per_second': '21706.00'},
{'test_name': 'httpgobin-t1-c50', 'threads': '1', 'connections': '50', 'latency': {'avg': '1.72ms', 'stddev': '1.74ms', 'max': '35.87ms'}, 'requests_per_second': '33616.50'},
{'test_name': 'httpgobin-t2-c50', 'threads': '2', 'connections': '50', 'latency': {'avg': '2.60ms', 'stddev': '4.95ms', 'max': '102.99ms'}, 'requests_per_second': '29533.77'},
{'test_name': 'httpgobin-t3-c50', 'threads': '3', 'connections': '50', 'latency': {'avg': '2.21ms', 'stddev': '2.48ms', 'max': '49.55ms'}, 'requests_per_second': '26853.67'},
{'test_name': 'httpgobin-t4-c50', 'threads': '4', 'connections': '50', 'latency': {'avg': '1.39ms', 'stddev': '674.88us', 'max': '13.93ms'}, 'requests_per_second': '35122.96'},
{'test_name': 'httpgobin-t1-c100', 'threads': '1', 'connections': '100', 'latency': {'avg': '4.72ms', 'stddev': '6.27ms', 'max': '118.24ms'}, 'requests_per_second': '27923.87'},
{'test_name': 'httpgobin-t2-c100', 'threads': '2', 'connections': '100', 'latency': {'avg': '4.47ms', 'stddev': '4.56ms', 'max': '80.37ms'}, 'requests_per_second': '27438.48'},
{'test_name': 'httpgobin-t3-c100', 'threads': '3', 'connections': '100', 'latency': {'avg': '2.87ms', 'stddev': '2.67ms', 'max': '73.39ms'}, 'requests_per_second': '37590.43'},
{'test_name': 'httpgobin-t4-c100', 'threads': '4', 'connections': '100', 'latency': {'avg': '3.84ms', 'stddev': '4.57ms', 'max': '120.11ms'}, 'requests_per_second': '31717.40'},
{'test_name': 'httpgobin-t1-c200', 'threads': '1', 'connections': '200', 'latency': {'avg': '7.56ms', 'stddev': '8.53ms', 'max': '245.81ms'}, 'errors': {'connect': '0,', 'read': '25,', 'write': '0,', 'timeout': '0'}, 'requests_per_second': '32936.70'},
{'test_name': 'httpgobin-t2-c200', 'threads': '2', 'connections': '200', 'latency': {'avg': '7.31ms', 'stddev': '7.19ms', 'max': '203.25ms'}, 'errors': {'connect': '0,', 'read': '45,', 'write': '0,', 'timeout': '0'}, 'requests_per_second': '32604.34'},
{'test_name': 'httpgobin-t3-c200', 'threads': '3', 'connections': '200', 'latency': {'avg': '6.17ms', 'stddev': '7.98ms', 'max': '236.26ms'}, 'errors': {'connect': '0,', 'read': '61,', 'write': '0,', 'timeout': '0'}, 'requests_per_second': '38511.00'},
{'test_name': 'httpgobin-t4-c200', 'threads': '4', 'connections': '200', 'latency': {'avg': '8.12ms', 'stddev': '10.81ms', 'max': '204.81ms'}, 'errors': {'connect': '0,', 'read': '102,', 'write': '0,', 'timeout': '0'}, 'requests_per_second': '33282.17'},
{'test_name': 'gateway-t1-c10', 'threads': '1', 'connections': '10', 'latency': {'avg': '9.84ms', 'stddev': '26.06ms', 'max': '575.66ms'}, 'requests_per_second': '1761.25'},
{'test_name': 'gateway-t2-c10', 'threads': '2', 'connections': '10', 'latency': {'avg': '8.96ms', 'stddev': '22.59ms', 'max': '277.92ms'}, 'requests_per_second': '2020.46'},
{'test_name': 'gateway-t3-c10', 'threads': '3', 'connections': '10', 'latency': {'avg': '7.79ms', 'stddev': '18.72ms', 'max': '228.40ms'}, 'requests_per_second': '1954.64'},
{'test_name': 'gateway-t4-c10', 'threads': '4', 'connections': '10', 'latency': {'avg': '15.89ms', 'stddev': '66.62ms', 'max': '1.12s'}, 'requests_per_second': '1145.35'},
{'test_name': 'gateway-t1-c20', 'threads': '1', 'connections': '20', 'latency': {'avg': '11.91ms', 'stddev': '19.47ms', 'max': '302.51ms'}, 'requests_per_second': '2277.15'},
{'test_name': 'gateway-t2-c20', 'threads': '2', 'connections': '20', 'latency': {'avg': '12.27ms', 'stddev': '20.70ms', 'max': '373.26ms'}, 'requests_per_second': '2227.49'},
{'test_name': 'gateway-t3-c20', 'threads': '3', 'connections': '20', 'latency': {'avg': '12.25ms', 'stddev': '22.67ms', 'max': '372.77ms'}, 'requests_per_second': '2104.14'},
{'test_name': 'gateway-t4-c20', 'threads': '4', 'connections': '20', 'latency': {'avg': '17.79ms', 'stddev': '36.53ms', 'max': '775.43ms'}, 'requests_per_second': '1755.80'},
{'test_name': 'gateway-t1-c50', 'threads': '1', 'connections': '50', 'latency': {'avg': '42.43ms', 'stddev': '71.23ms', 'max': '1.29s'}, 'requests_per_second': '1727.95'},
{'test_name': 'gateway-t2-c50', 'threads': '2', 'connections': '50', 'latency': {'avg': '24.61ms', 'stddev': '22.16ms', 'max': '305.59ms'}, 'requests_per_second': '2305.28'},
{'test_name': 'gateway-t3-c50', 'threads': '3', 'connections': '50', 'latency': {'avg': '23.66ms', 'stddev': '21.91ms', 'max': '313.56ms'}, 'requests_per_second': '2301.80'},
{'test_name': 'gateway-t4-c50', 'threads': '4', 'connections': '50', 'latency': {'avg': '24.79ms', 'stddev': '25.43ms', 'max': '437.93ms'}, 'requests_per_second': '2263.48'},
{'test_name': 'gateway-t1-c100', 'threads': '1', 'connections': '100', 'latency': {'avg': '126.32ms', 'stddev': '157.40ms', 'max': '1.73s'}, 'requests_per_second': '1071.62'},
{'test_name': 'gateway-t2-c100', 'threads': '2', 'connections': '100', 'latency': {'avg': '49.58ms', 'stddev': '36.90ms', 'max': '556.42ms'}, 'requests_per_second': '2208.82'},
{'test_name': 'gateway-t3-c100', 'threads': '3', 'connections': '100', 'latency': {'avg': '50.91ms', 'stddev': '34.95ms', 'max': '403.29ms'}, 'requests_per_second': '2091.84'},
{'test_name': 'gateway-t4-c100', 'threads': '4', 'connections': '100', 'latency': {'avg': '47.49ms', 'stddev': '31.10ms', 'max': '444.50ms'}, 'requests_per_second': '2248.33'},
{'test_name': 'gateway-t1-c200', 'threads': '1', 'connections': '200', 'latency': {'avg': '111.77ms', 'stddev': '115.57ms', 'max': '1.97s'}, 'errors': {'connect': '0,', 'read': '27,', 'write': '0,', 'timeout': '0'}, 'requests_per_second': '2077.75'},
{'test_name': 'gateway-t2-c200', 'threads': '2', 'connections': '200', 'latency': {'avg': '193.30ms', 'stddev': '187.10ms', 'max': '1.93s'}, 'errors': {'connect': '0,', 'read': '0,', 'write': '0,', 'timeout': '30'}, 'requests_per_second': '1229.44'},
{'test_name': 'gateway-t3-c200', 'threads': '3', 'connections': '200', 'latency': {'avg': '91.51ms', 'stddev': '47.69ms', 'max': '1.14s'}, 'errors': {'connect': '0,', 'read': '62,', 'write': '0,', 'timeout': '0'}, 'requests_per_second': '2234.63'},
{'test_name': 'gateway-t4-c200', 'threads': '4', 'connections': '200', 'latency': {'avg': '88.83ms', 'stddev': '46.36ms', 'max': '911.58ms'}, 'errors': {'connect': '0,', 'read': '67,', 'write': '0,', 'timeout': '0'}, 'requests_per_second': '2334.17'},
]

for item in data:
    item['latency']['avg'] = convert_to_ms(item['latency']['avg'])
    item['latency']['stddev'] = convert_to_ms(item['latency']['stddev'])
    item['latency']['max'] = convert_to_ms(item['latency']['max'])

# %%
def get_data_by_threads(service, threads):
    X = []
    Ylat = []
    Yrps = []
    for item in data:
        if item['test_name'].startswith(service) and int(item['threads']) == threads:
            X.append(int(item['connections']))
            Ylat.append(item['latency'])
            Yrps.append(float(item['requests_per_second']))
    
    Ylat_avg = [y['avg'] for y in Ylat]
    stddevs = [y['stddev'] for y in Ylat]
    Ylat_ub = [avg + std for avg, std in zip(Ylat_avg, stddevs)]
    Ylat_lb = [max(0.0,avg - std) for avg, std in zip(Ylat_avg, stddevs)]

    return X,Yrps,Ylat_avg,Ylat_lb,Ylat_ub

# %%
import matplotlib.pyplot as plt

service = 'gateway'
threads = [1,2,3,4]


# Plotting
fig, ax = plt.subplots(nrows=len(threads), ncols=2, figsize=(16, 9), squeeze=False, sharex='col', sharey='col')
fig.suptitle(f'{service} tests')
for idx,t in enumerate(threads):
    X,Yrps,Ylat_avg,Ylat_lb,Ylat_ub = get_data_by_threads(service=service, threads=t)

    ax[idx,0].plot(X, Ylat_avg, '-', label=f'Threads={t}', color='blue')
    ax[idx,0].fill_between(X, Ylat_lb, Ylat_ub, color='blue', alpha=0.1)
    ax[idx,0].legend()

    ax[idx,1].plot(X, Yrps, '-', label='Max', color='blue')

    if idx == 0:
        ax[idx,0].set_title('Latency')
        ax[idx,1].set_title('Requests per second')
    if idx == len(threads) - 1:
        ax[idx,0].set(xlabel='Connections', ylabel='Latency [ms]')
        ax[idx,1].set(xlabel='Connections', ylabel='RPS [1]')
    else:
        ax[idx,0].set(ylabel='Latency [ms]')
        ax[idx,1].set(ylabel='RPS [1]')

# %%
service = 'httpgobin'
threads = [1,2,3,4]


# Plotting
fig, ax = plt.subplots(nrows=len(threads), ncols=2, figsize=(16, 9), squeeze=False, sharex='col', sharey='col')
fig.suptitle(f'{service} tests')
for idx,t in enumerate(threads):
    X,Yrps,Ylat_avg,Ylat_lb,Ylat_ub = get_data_by_threads(service=service, threads=t)

    ax[idx,0].plot(X, Ylat_avg, '-', label=f'Threads={t}', color='blue')
    ax[idx,0].fill_between(X, Ylat_lb, Ylat_ub, color='blue', alpha=0.1)
    ax[idx,0].legend()

    ax[idx,1].plot(X, Yrps, '-', label='Max', color='blue')

    if idx == 0:
        ax[idx,0].set_title('Latency')
        ax[idx,1].set_title('Requests per second')
    if idx == len(threads) - 1:
        ax[idx,0].set(xlabel='Connections', ylabel='Latency [ms]')
        ax[idx,1].set(xlabel='Connections', ylabel='RPS [1]')
    else:
        ax[idx,0].set(ylabel='Latency [ms]')
        ax[idx,1].set(ylabel='RPS [1]')
